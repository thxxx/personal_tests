# %%
# celelb에서 이미지 읽어오는 Dataloader 만들기
# vae latent shape에 대응하도록 모델 짜기
import torch
import numpy as np
import matplotlib.pyplot as plt
import torch.nn as nn
from tqdm import tqdm
from diffusers import AutoencoderKL
from model.unet import Unet
import os
from utils.utils import visualize
from utils.sample import ddim_sample, x_t_sample
import torch.nn.functional as F
from dataset import CelebDataset
from torchvision import transforms
from utils.schedule import linear_beta_schedule, cosine_beta_schedule
from ldm.attention import DiT
from einops import rearrange
import time

from types import SimpleNamespace

def count_parameters(model: nn.Module, only_trainable: bool = True):
    return f"{round(sum(p.numel() for p in model.parameters() if p.requires_grad or not only_trainable)/1000000, 3)}M"

cfg = {
    "in_dim":4,
    "model_dim": 256,
    "depth":20,
    "num_heads":8,
    "batch_size": 256,
    "learning_rate": 1e-4,
    "epochs": 1000,
    "total_timesteps": 1000,
    "beta_0": 0.0001,
    "beta_T": 0.02,
    "sampling_steps": 1000,
    "latent_scale": 0.18215,
    "output_dir": "./logs_dit",
    "beta_1": 0.9,
    "beta_2": 0.95,
    'weight_decay': 0.1,
}
cfg = SimpleNamespace(**cfg)

# %%
device = 'cuda'

# downsampling rate=8, latent_dim=4
vae = AutoencoderKL.from_pretrained("CompVis/stable-diffusion-v1-4", subfolder="vae").to(device)

model = DiT(
    in_dim=cfg.in_dim, 
    model_dim=cfg.model_dim, 
    depth=cfg.depth, 
    num_heads=cfg.num_heads
)
model.to(device)
print(count_parameters(model))

os.makedirs(cfg.output_dir, exist_ok=True)
os.makedirs(f"{cfg.output_dir}/valid_imgs/", exist_ok=True)
os.makedirs(f"{cfg.output_dir}/weights/", exist_ok=True)

optimizer = torch.optim.AdamW(model.parameters(), lr=cfg.learning_rate, betas=(cfg.beta_1, cfg.beta_2), weight_decay=cfg.weight_decay)

trainer = {
    'train_losses': [],
    'valid_losses': [],
    'valid_images': [],
}
# Out:
# 1.013M

# %%
from datasets import load_dataset
from torchvision import transforms
from torch.utils.data import DataLoader
from PIL import Image
import cv2
import torch

def load_image_as_tensor(path):
    img = cv2.imread(path, cv2.IMREAD_COLOR)  # BGR 형식
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # RGB로 변환
    img = torch.from_numpy(img).permute(2, 0, 1).float() / 255.0  # (H, W, C) -> (C, H, W)
    return img

transform = transforms.Compose([
    transforms.Resize(64),
    transforms.CenterCrop(64),
    RandomHorizontalFlip(p=0.1)
])

class CelebDataset(torch.utils.data.Dataset):
    def __init__(self, data_paths, transform=None):
        self.dataset = data_paths
        self.transform = transform
    
    def __len__(self):
        return len(self.dataset)
    
    def __getitem__(self, idx):
        try:
            img = load_image_as_tensor(self.dataset[idx])
        except Exception as e:
            print("Error : ", e)
            return self.__getitem__(idx + 1)
        return self.transform(img)

train_paths = [f'img_align_celeba/{i:06d}.jpg' for i in range(162770)]
valid_paths = [f'img_align_celeba/{i:06d}.jpg' for i in range(162771, 182637)]
train_dataset = CelebDataset(train_paths, transform)
valid_dataset = CelebDataset(valid_paths, transform)

train_dataloader = DataLoader(train_dataset, batch_size=cfg.batch_size, shuffle=True, num_workers=8)
valid_dataloader = DataLoader(valid_dataset, batch_size=cfg.batch_size, shuffle=False, num_workers=8)

# %%
betas, alphas, alphas_bar = cosine_beta_schedule(cfg.total_timesteps)
print("betas : ", betas.shape)
print("alphas : ", alphas.shape)

def write(text):
    with open(f'{cfg.output_dir}/logs.txt', 'a') as file:
        file.write(text)

from datetime import datetime
write(f"\n\nTraining start : {datetime.today().strftime('%Y-%m-%d %H:%M')}\n\n")

torch.cuda.empty_cache()
# Out:
# betas :  torch.Size([1000])
# alphas :  torch.Size([1000])

# %%
import matplotlib.pyplot as plt
import torchvision.transforms.functional as F

# 예: image shape = (3, H, W), 값은 [0, 1]
def show_tensor_image(img_tensor):
    # tensor → numpy
    img = img_tensor.detach().cpu()
    if img.ndim == 4:  # 배치가 있을 경우 첫 번째 이미지만
        img = img[0]
    img = F.to_pil_image(img)
    plt.imshow(img)
    plt.axis("off")
    plt.show()

show_tensor_image(valid_dataset[1])

# %%
last_saved_epoch = 0
vae.eval()

def valid_step(epoch):
    model.eval()
    valid_loss = 0
    tqdm_bar = tqdm(total=len(valid_dataloader), desc="Diffusion validation")
    with torch.no_grad():
        for idx, data in enumerate(valid_dataloader):
            x_0 = data.to(device)
            with torch.no_grad():
                z_0 = vae.encode(x_0)
                z_0 = z_0['latent_dist'].sample() * cfg.latent_scale
            
            b, c, h, w = z_0.shape
            z_0 = z_0.permute(0, 2, 3, 1).reshape(b, h*w, c)
            
            timesteps = torch.randint(1, 1000, (b,))
            added_noise = torch.randn_like(z_0)
            
            z_t = x_t_sample(z_0, timesteps, added_noise, alphas_bar)
            z_t = z_t.to(device)
            timesteps = timesteps.to(device)
            added_noise = added_noise.to(device)
    
            predicted_noise = model(z_t, timesteps)
            
            loss = torch.nn.functional.mse_loss(added_noise, predicted_noise)
            
            valid_loss += loss.cpu().detach().item()
            tqdm_bar.update()

            # Inference Sampling for visual evaluation
            if idx==0:
                ddim_timesteps = torch.linspace(999, 0, 100).long().to(device)
                z_t = torch.randn_like(z_0).to(device) # start from z_T
                
                for i in range(len(ddim_timesteps) - 1):
                    t = ddim_timesteps[i]
                    t_next = ddim_timesteps[i+1]
                
                    t_batch = torch.full((b,), t.item(), dtype=torch.float32, device=device)
                    pred_noise = model(z_t, t_batch)
                
                    ab_t = alphas_bar[t].expand(b)
                    ab_t_next = alphas_bar[t_next].expand(b)
                    z_t = ddim_sample(z_t, t_batch, pred_noise, ab_t, ab_t_next).to(torch.float32)
    
                z_t = rearrange(z_t, "b (x y) c -> b c x y", x=w, y=h)
                
                predicted_image = vae.decode(z_t)
                trainer['valid_images'].append(predicted_image['sample'][:8].cpu().detach()/2+0.5)
                del ddim_timesteps
                del predicted_image
    
    del loss
    del predicted_noise
    del added_noise
    del timesteps
    del z_t
    torch.cuda.empty_cache()
    
    # per data loss
    val_loss = valid_loss/(len(valid_dataloader) * cfg.batch_size)
    
    trainer['valid_losses'].append(val_loss)
    
    if val_loss <= min(trainer['valid_losses']):
        torch.save(model.state_dict(), f'{cfg.output_dir}/weights/model_{epoch}.pth')
    
    valid_text=f'Epoch {epoch} Validation loss - {val_loss}\n\n'
    write(valid_text)
    
    plt.plot(trainer['train_losses'])
    plt.savefig(f'{cfg.output_dir}/train_loss.png')
    plt.close()
    
    plt.plot(trainer['valid_losses'])
    plt.savefig(f'{cfg.output_dir}/valid_loss.png')
    plt.close()
    
    visualize(trainer['valid_images'][-1], epoch=epoch, save=True, output_dir=cfg.output_dir)

# %%
import time

vae.eval()
last_saved_epoch = 0

sigma_min = 1e-5
# timestep은 0~1000이 아니라 0~1 사이 실수 값 : t = torch.rand((b, ), dtype=z_0.dtype, device=device)
# t = rearrange(t, "b -> b () ()")
# zt = (1 - (1 - sigma_min)*t) * z_T) + t * z_0
# target_flow = z_0 - (1 - sigma_min) * z_T

for epoch in range(cfg.epochs):
    model.train()
    epoch_loss = 0
    tqdm_bar = tqdm(total=len(train_dataloader), desc="Latent DiT DDPM Training")
    
    for idx, data in enumerate(train_dataloader):
        x_0 = data.to(device)

        # 2) VAE encode
        with torch.no_grad():
            z_0 = vae.encode(x_0)
            z_0 = z_0['latent_dist'].sample() * cfg.latent_scale

        # Flatten latent
        b, c, h, w = z_0.shape
        z_0 = z_0.permute(0, 2, 3, 1).reshape(b, h*w, c)

        # 3) DDPM noising
        timesteps = torch.randint(1, 1000, (b,))
        added_noise = torch.randn_like(z_0)
        z_t = x_t_sample(z_0, timesteps, added_noise, alphas_bar)
        z_t = z_t.to(device)
        timesteps = timesteps.to(device)
        added_noise = added_noise.to(device)

        # 4) 모델 예측
        predicted_noise = model(z_t, timesteps)

        # Loss 계산
        loss = torch.nn.functional.mse_loss(added_noise, predicted_noise)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        tqdm_bar.update()
        epoch_loss += loss.cpu().detach().item()

    train_text = f'Epoch {epoch} Train loss - {epoch_loss / len(train_dataloader)}\n'
    write(train_text)

    del loss, predicted_noise, added_noise, timesteps, z_t
    torch.cuda.empty_cache()

    valid_step(epoch)
# Out:
# Latent DiT DDPM Training:  60%|█████▉    | 379/636 [02:32<02:06,  2.03it/s]
# Error :  OpenCV(4.11.0) /io/opencv/modules/imgproc/src/color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
# [ WARN:0@152.641] global loadsave.cpp:268 findDecoder imread_('img_align_celeba/000000.jpg'): can't open/read file: check file path/integrity
# Latent DiT DDPM Training: 100%|██████████| 636/636 [04:11<00:00,  2.71it/s]
# Diffusion validation:   0%|          | 0/78 [00:00<?, ?it/s]
# Diffusion validation:   1%|▏         | 1/78 [00:02<03:21,  2.62s/it]
# Diffusion validation:   3%|▎         | 2/78 [00:05<03:23,  2.67s/it]
# Diffusion validation:   4%|▍         | 3/78 [00:05<01:56,  1.55s/it]
# Diffusion validation:   5%|▌         | 4/78 [00:05<01:15,  1.02s/it]
# Diffusion validation:   6%|▋         | 5/78 [00:05<00:53,  1.38it/s]
# Diffusion validation:   8%|▊         | 6/78 [00:06<00:39,  1.82it/s]
# Diffusion validation:   9%|▉         | 7/78 [00:06<00:31,  2.29it/s]
# Diffusion validation:  10%|█         | 8/78 [00:06<00:25,  2.75it/s]
# Diffusion validation:  12%|█▏        | 9/78 [00:06<00:21,  3.18it/s]
# Diffusion validation:  13%|█▎        | 10/78 [00:06<00:19,  3.56it/s]
# Diffusion validation:  14%|█▍        | 11/78 [00:07<00:17,  3.88it/s]
# Diffusion validation:  15%|█▌        | 12/78 [00:07<00:15,  4.13it/s]
# Diffusion validation:  17%|█▋        | 13/78 [00:07<00:15,  4.33it/s]
# Diffusion validation:  18%|█▊        | 14/78 [00:07<00:14,  4.48it/s]
# Diffusion validation:  19%|█▉        | 15/78 [00:08<00:13,  4.59it/s]
# Diffusion validation:  21%|██        | 16/78 [00:08<00:13,  4.66it/s]
# Diffusion validation:  22%|██▏       | 17/78 [00:08<00:12,  4.71it/s]
# Diffusion validation:  23%|██▎       | 18/78 [00:08<00:12,  4.75it/s]
# Diffusion validation:  24%|██▍       | 19/78 [00:08<00:12,  4.77it/s]
# Diffusion validation:  26%|██▌       | 20/78 [00:09<00:12,  4.80it/s]
# Diffusion validation:  27%|██▋       | 21/78 [00:09<00:11,  4.81it/s]
# Diffusion validation:  28%|██▊       | 22/78 [00:09<00:11,  4.83it/s]
# Diffusion validation:  29%|██▉       | 23/78 [00:09<00:11,  4.83it/s]
# Diffusion validation:  31%|███       | 24/78 [00:09<00:11,  4.84it/s]
# Diffusion validation:  32%|███▏      | 25/78 [00:10<00:10,  4.84it/s]
# Diffusion validation:  33%|███▎      | 26/78 [00:10<00:10,  4.84it/s]
# Diffusion validation:  35%|███▍      | 27/78 [00:10<00:12,  4.15it/s]
# Diffusion validation:  36%|███▌      | 28/78 [00:10<00:11,  4.31it/s]
# Diffusion validation:  37%|███▋      | 29/78 [00:11<00:11,  4.43it/s]
# Diffusion validation:  38%|███▊      | 30/78 [00:11<00:10,  4.53it/s]
# Diffusion validation:  40%|███▉      | 31/78 [00:11<00:10,  4.59it/s]
# Diffusion validation:  41%|████      | 32/78 [00:11<00:09,  4.64it/s]
# Diffusion validation:  42%|████▏     | 33/78 [00:11<00:10,  4.20it/s]
# Diffusion validation:  44%|████▎     | 34/78 [00:12<00:10,  4.37it/s]
# Diffusion validation:  45%|████▍     | 35/78 [00:13<00:21,  1.99it/s]
# Diffusion validation:  46%|████▌     | 36/78 [00:13<00:17,  2.41it/s]
# Diffusion validation:  47%|████▋     | 37/78 [00:13<00:14,  2.83it/s]
# Diffusion validation:  49%|████▊     | 38/78 [00:13<00:12,  3.22it/s]
# Diffusion validation:  50%|█████     | 39/78 [00:14<00:10,  3.56it/s]
# Diffusion validation:  51%|█████▏    | 40/78 [00:14<00:09,  3.85it/s]
# Diffusion validation:  53%|█████▎    | 41/78 [00:14<00:09,  4.08it/s]
# Diffusion validation:  54%|█████▍    | 42/78 [00:14<00:08,  4.28it/s]
# Diffusion validation:  55%|█████▌    | 43/78 [00:15<00:17,  2.06it/s]
# Diffusion validation:  56%|█████▋    | 44/78 [00:16<00:13,  2.48it/s]
# Diffusion validation:  58%|█████▊    | 45/78 [00:16<00:11,  2.89it/s]
# Diffusion validation:  59%|█████▉    | 46/78 [00:16<00:09,  3.28it/s]
# Diffusion validation:  60%|██████    | 47/78 [00:16<00:08,  3.62it/s]
# Diffusion validation:  62%|██████▏   | 48/78 [00:16<00:07,  3.91it/s]
# Diffusion validation:  63%|██████▎   | 49/78 [00:17<00:07,  4.12it/s]
# Diffusion validation:  64%|██████▍   | 50/78 [00:17<00:06,  4.31it/s]
# Diffusion validation:  65%|██████▌   | 51/78 [00:18<00:13,  1.99it/s]
# Diffusion validation:  67%|██████▋   | 52/78 [00:18<00:10,  2.41it/s]
# Diffusion validation:  68%|██████▊   | 53/78 [00:18<00:08,  2.84it/s]
# Diffusion validation:  69%|██████▉   | 54/78 [00:19<00:07,  3.24it/s]
# Diffusion validation:  71%|███████   | 55/78 [00:19<00:06,  3.59it/s]
# Diffusion validation:  72%|███████▏  | 56/78 [00:19<00:05,  3.87it/s]
# Diffusion validation:  73%|███████▎  | 57/78 [00:19<00:05,  4.09it/s]
# Diffusion validation:  74%|███████▍  | 58/78 [00:19<00:04,  4.28it/s]
# Diffusion validation:  76%|███████▌  | 59/78 [00:21<00:09,  1.91it/s]
# Diffusion validation:  77%|███████▋  | 60/78 [00:21<00:07,  2.32it/s]
# Diffusion validation:  78%|███████▊  | 61/78 [00:21<00:06,  2.75it/s]
# Diffusion validation:  79%|███████▉  | 62/78 [00:21<00:05,  3.15it/s]
# Diffusion validation:  81%|████████  | 63/78 [00:21<00:04,  3.51it/s]
# Diffusion validation:  82%|████████▏ | 64/78 [00:22<00:03,  3.81it/s]
# Diffusion validation:  83%|████████▎ | 65/78 [00:22<00:03,  4.05it/s]
# Diffusion validation:  85%|████████▍ | 66/78 [00:22<00:02,  4.25it/s]
# Diffusion validation:  86%|████████▌ | 67/78 [00:23<00:06,  1.83it/s]
# Diffusion validation:  87%|████████▋ | 68/78 [00:24<00:04,  2.17it/s]
# Diffusion validation:  88%|████████▊ | 69/78 [00:24<00:03,  2.59it/s]
# Diffusion validation:  90%|████████▉ | 70/78 [00:24<00:02,  3.00it/s]
# Diffusion validation:  91%|█████████ | 71/78 [00:24<00:02,  3.37it/s]
# Diffusion validation:  92%|█████████▏| 72/78 [00:24<00:01,  3.70it/s]
# Diffusion validation:  94%|█████████▎| 73/78 [00:25<00:01,  3.97it/s]
# Diffusion validation:  95%|█████████▍| 74/78 [00:25<00:00,  4.18it/s]
# Diffusion validation:  96%|█████████▌| 75/78 [00:26<00:01,  1.90it/s]
# Diffusion validation:  97%|█████████▋| 76/78 [00:26<00:00,  2.08it/s]
# Diffusion validation:  99%|█████████▊| 77/78 [00:27<00:00,  2.51it/s]
# Diffusion validation: 100%|██████████| 78/78 [00:27<00:00,  3.12it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.3561225..3.321103].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.4783117..2.9546351].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.6920278..3.3529694].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.2389337..3.1112442].
# Diffusion validation: 100%|██████████| 78/78 [00:27<00:00,  2.80it/s]
#
# Latent DiT DDPM Training: 100%|██████████| 636/636 [04:40<00:00,  2.27it/s]
#
# Latent DiT DDPM Training:   0%|          | 1/636 [00:03<36:23,  3.44s/it]
# Latent DiT DDPM Training:   0%|          | 2/636 [00:03<16:35,  1.57s/it]
# Latent DiT DDPM Training:   0%|          | 3/636 [00:03<10:15,  1.03it/s]
# Latent DiT DDPM Training:   1%|          | 4/636 [00:04<07:16,  1.45it/s]
# Latent DiT DDPM Training:   1%|          | 5/636 [00:04<05:37,  1.87it/s]
# Latent DiT DDPM Training:   1%|          | 6/636 [00:04<04:38,  2.26it/s]
# Latent DiT DDPM Training:   1%|          | 7/636 [00:05<04:01,  2.61it/s]
# Latent DiT DDPM Training:   1%|▏         | 8/636 [00:05<03:35,  2.91it/s]
# Latent DiT DDPM Training:   1%|▏         | 9/636 [00:05<04:26,  2.35it/s]
# Latent DiT DDPM Training:   2%|▏         | 10/636 [00:06<03:53,  2.68it/s]
# Latent DiT DDPM Training:   2%|▏         | 11/636 [00:06<03:31,  2.95it/s]
# Latent DiT DDPM Training:   2%|▏         | 12/636 [00:06<03:15,  3.18it/s]
# Latent DiT DDPM Training:   2%|▏         | 13/636 [00:06<03:06,  3.35it/s]
# Latent DiT DDPM Training:   2%|▏         | 14/636 [00:07<02:57,  3.51it/s]
# Latent DiT DDPM Training:   2%|▏         | 15/636 [00:07<02:51,  3.62it/s]
# Latent DiT DDPM Training:   3%|▎         | 16/636 [00:07<02:47,  3.69it/s]
# Latent DiT DDPM Training:   3%|▎         | 17/636 [00:08<05:02,  2.05it/s]
# Latent DiT DDPM Training:   3%|▎         | 18/636 [00:08<04:19,  2.38it/s]
# Latent DiT DDPM Training:   3%|▎         | 19/636 [00:09<03:48,  2.70it/s]
# Latent DiT DDPM Training:   3%|▎         | 20/636 [00:09<03:27,  2.97it/s]
# Latent DiT DDPM Training:   3%|▎         | 21/636 [00:09<03:13,  3.18it/s]
# Latent DiT DDPM Training:   3%|▎         | 22/636 [00:09<03:03,  3.35it/s]
# Latent DiT DDPM Training:   4%|▎         | 23/636 [00:10<02:55,  3.49it/s]
# Latent DiT DDPM Training:   4%|▍         | 24/636 [00:10<02:50,  3.60it/s]
# Latent DiT DDPM Training:   4%|▍         | 25/636 [00:11<04:26,  2.29it/s]
# Latent DiT DDPM Training:   4%|▍         | 26/636 [00:11<03:53,  2.61it/s]
# Latent DiT DDPM Training:   4%|▍         | 27/636 [00:11<03:31,  2.88it/s]
# Latent DiT DDPM Training:   4%|▍         | 28/636 [00:12<03:14,  3.13it/s]
# Latent DiT DDPM Training:   5%|▍         | 29/636 [00:12<03:03,  3.31it/s]
# Latent DiT DDPM Training:   5%|▍         | 30/636 [00:12<02:53,  3.49it/s]
# Latent DiT DDPM Training:   5%|▍         | 31/636 [00:12<02:47,  3.61it/s]
# Latent DiT DDPM Training:   5%|▌         | 32/636 [00:13<02:43,  3.68it/s]
# Latent DiT DDPM Training:   5%|▌         | 33/636 [00:13<03:21,  3.00it/s]
# Latent DiT DDPM Training:   5%|▌         | 34/636 [00:13<03:06,  3.23it/s]
# Latent DiT DDPM Training:   6%|▌         | 35/636 [00:14<02:57,  3.39it/s]
# Latent DiT DDPM Training:   6%|▌         | 36/636 [00:14<02:49,  3.54it/s]
# Latent DiT DDPM Training:   6%|▌         | 37/636 [00:14<02:44,  3.64it/s]
# Latent DiT DDPM Training:   6%|▌         | 38/636 [00:14<02:40,  3.72it/s]
# Latent DiT DDPM Training:   6%|▌         | 39/636 [00:15<02:37,  3.78it/s]
# Latent DiT DDPM Training:   6%|▋         | 40/636 [00:15<02:36,  3.81it/s]
# Latent DiT DDPM Training:   6%|▋         | 41/636 [00:15<03:26,  2.88it/s]
# Latent DiT DDPM Training:   7%|▋         | 42/636 [00:16<03:09,  3.13it/s]
# Latent DiT DDPM Training:   7%|▋         | 43/636 [00:16<02:58,  3.33it/s]
# Latent DiT DDPM Training:   7%|▋         | 44/636 [00:16<02:49,  3.48it/s]
# Latent DiT DDPM Training:   7%|▋         | 45/636 [00:16<02:41,  3.65it/s]
# Latent DiT DDPM Training:   7%|▋         | 46/636 [00:17<02:40,  3.68it/s]
# Latent DiT DDPM Training:   7%|▋         | 47/636 [00:17<02:36,  3.75it/s]
# Latent DiT DDPM Training:   8%|▊         | 48/636 [00:17<02:34,  3.80it/s]
# Latent DiT DDPM Training:   8%|▊         | 49/636 [00:18<03:23,  2.89it/s]
# Latent DiT DDPM Training:   8%|▊         | 50/636 [00:18<03:07,  3.13it/s]
# Latent DiT DDPM Training:   8%|▊         | 51/636 [00:18<02:56,  3.32it/s]
# Latent DiT DDPM Training:   8%|▊         | 52/636 [00:19<02:49,  3.45it/s]
# Latent DiT DDPM Training:   8%|▊         | 53/636 [00:19<02:44,  3.54it/s]
# Latent DiT DDPM Training:   8%|▊         | 54/636 [00:19<02:41,  3.61it/s]
# Latent DiT DDPM Training:   9%|▊         | 55/636 [00:19<02:37,  3.68it/s]
# Latent DiT DDPM Training:   9%|▉         | 56/636 [00:20<02:35,  3.74it/s]
# Latent DiT DDPM Training:   9%|▉         | 57/636 [00:20<02:35,  3.73it/s]
# Latent DiT DDPM Training:   9%|▉         | 58/636 [00:20<02:33,  3.77it/s]
# Latent DiT DDPM Training:   9%|▉         | 59/636 [00:20<02:32,  3.78it/s]
# Latent DiT DDPM Training:   9%|▉         | 60/636 [00:21<02:33,  3.75it/s]
# Latent DiT DDPM Training:  10%|▉         | 61/636 [00:21<02:57,  3.24it/s]
# Latent DiT DDPM Training:  10%|▉         | 62/636 [00:21<02:48,  3.40it/s]
# Latent DiT DDPM Training:  10%|▉         | 63/636 [00:22<02:43,  3.51it/s]
# Latent DiT DDPM Training:  10%|█         | 64/636 [00:22<02:39,  3.60it/s]
# Latent DiT DDPM Training:  10%|█         | 65/636 [00:22<02:50,  3.35it/s]
# Latent DiT DDPM Training:  10%|█         | 66/636 [00:22<02:45,  3.45it/s]
# Latent DiT DDPM Training:  11%|█         | 67/636 [00:23<02:40,  3.54it/s]
/s]
# Latent DiT DDPM Training:  88%|████████▊ | 561/636 [03:00<00:20,  3.65it/s]
# Latent DiT DDPM Training:  88%|████████▊ | 562/636 [03:01<00:19,  3.72it/s]
# Latent DiT DDPM Training:  89%|████████▊ | 563/636 [03:01<00:26,  2.79it/s]
# Latent DiT DDPM Training:  89%|████████▊ | 564/636 [03:01<00:23,  3.04it/s]
# Latent DiT DDPM Training:  89%|████████▉ | 565/636 [03:02<00:21,  3.26it/s]
# Latent DiT DDPM Training:  89%|████████▉ | 566/636 [03:02<00:20,  3.43it/s]
# Latent DiT DDPM Training:  89%|████████▉ | 567/636 [03:02<00:19,  3.56it/s]
# Latent DiT DDPM Training:  89%|████████▉ | 568/636 [03:02<00:18,  3.66it/s]
# Latent DiT DDPM Training:  89%|████████▉ | 569/636 [03:03<00:18,  3.64it/s]
# Latent DiT DDPM Training:  90%|████████▉ | 570/636 [03:03<00:20,  3.18it/s]
# Latent DiT DDPM Training:  90%|████████▉ | 571/636 [03:04<00:27,  2.36it/s]
# Latent DiT DDPM Training:  90%|████████▉ | 572/636 [03:04<00:24,  2.66it/s]
# Latent DiT DDPM Training:  90%|█████████ | 573/636 [03:04<00:21,  2.95it/s]
# Latent DiT DDPM Training:  90%|█████████ | 574/636 [03:04<00:19,  3.18it/s]
# Latent DiT DDPM Training:  90%|█████████ | 575/636 [03:05<00:18,  3.36it/s]
# Latent DiT DDPM Training:  91%|█████████ | 576/636 [03:05<00:17,  3.51it/s]
# Latent DiT DDPM Training:  91%|█████████ | 577/636 [03:06<00:20,  2.85it/s]
# Latent DiT DDPM Training:  91%|█████████ | 578/636 [03:06<00:18,  3.10it/s]
# Latent DiT DDPM Training:  91%|█████████ | 579/636 [03:06<00:24,  2.35it/s]
# Latent DiT DDPM Training:  91%|█████████ | 580/636 [03:07<00:20,  2.68it/s]
# Latent DiT DDPM Training:  91%|█████████▏| 581/636 [03:07<00:18,  2.95it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 582/636 [03:07<00:16,  3.19it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 583/636 [03:07<00:15,  3.38it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 584/636 [03:08<00:14,  3.52it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 585/636 [03:08<00:18,  2.76it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 586/636 [03:09<00:16,  3.02it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 587/636 [03:09<00:21,  2.27it/s]
# Latent DiT DDPM Training:  92%|█████████▏| 588/636 [03:09<00:18,  2.59it/s]
# Latent DiT DDPM Training:  93%|█████████▎| 589/636 [03:10<00:16,  2.88it/s]
# Latent DiT DDPM Training:  93%|█████████▎| 590/636 [03:10<00:14,  3.11it/s]
# Latent DiT DDPM Training:  93%|█████████▎| 591/636 [03:10<00:13,  3.29it/s]
# Latent DiT DDPM Training:  93%|█████████▎| 592/636 [03:11<00:12,  3.46it/s]
# Latent DiT DDPM Training:  93%|█████████▎| 593/636 [03:11<00:14,  2.92it/s]
# Latent DiT DDPM Training:  93%|█████████▎| 594/636 [03:11<00:13,  3.13it/s]
# Latent DiT DDPM Training:  94%|█████████▎| 595/636 [03:12<00:15,  2.58it/s]
# Latent DiT DDPM Training:  94%|█████████▎| 596/636 [03:12<00:13,  2.86it/s]
# Latent DiT DDPM Training:  94%|█████████▍| 597/636 [03:12<00:12,  3.10it/s]
# Latent DiT DDPM Training:  94%|█████████▍| 598/636 [03:13<00:11,  3.30it/s]
# Latent DiT DDPM Training:  94%|█████████▍| 599/636 [03:13<00:10,  3.46it/s]
# Latent DiT DDPM Training:  94%|█████████▍| 600/636 [03:13<00:10,  3.53it/s]
# Latent DiT DDPM Training:  94%|█████████▍| 601/636 [03:14<00:11,  3.00it/s]
# Latent DiT DDPM Training:  95%|█████████▍| 602/636 [03:14<00:10,  3.20it/s]
# Latent DiT DDPM Training:  95%|█████████▍| 603/636 [03:14<00:13,  2.42it/s]
# Latent DiT DDPM Training:  95%|█████████▍| 604/636 [03:15<00:11,  2.73it/s]
# Latent DiT DDPM Training:  95%|█████████▌| 605/636 [03:15<00:10,  3.00it/s]
# Latent DiT DDPM Training:  95%|█████████▌| 606/636 [03:15<00:09,  3.21it/s]
# Latent DiT DDPM Training:  95%|█████████▌| 607/636 [03:15<00:08,  3.39it/s]
# Latent DiT DDPM Training:  96%|█████████▌| 608/636 [03:16<00:07,  3.50it/s]
# Latent DiT DDPM Training:  96%|█████████▌| 609/636 [03:16<00:11,  2.41it/s]
# Latent DiT DDPM Training:  96%|█████████▌| 610/636 [03:17<00:09,  2.73it/s]
# Latent DiT DDPM Training:  96%|█████████▌| 611/636 [03:17<00:09,  2.56it/s]
# Latent DiT DDPM Training:  96%|█████████▌| 612/636 [03:17<00:08,  2.85it/s]
# Latent DiT DDPM Training:  96%|█████████▋| 613/636 [03:18<00:07,  3.11it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 614/636 [03:18<00:06,  3.31it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 615/636 [03:18<00:06,  3.47it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 616/636 [03:18<00:05,  3.59it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 617/636 [03:19<00:09,  2.04it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 618/636 [03:20<00:07,  2.38it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 619/636 [03:20<00:06,  2.43it/s]
# Latent DiT DDPM Training:  97%|█████████▋| 620/636 [03:20<00:06,  2.54it/s]
# Latent DiT DDPM Training:  98%|█████████▊| 621/636 [03:21<00:05,  2.83it/s]
# Latent DiT DDPM Training:  98%|█████████▊| 622/636 [03:21<00:04,  3.09it/s]
# Latent DiT DDPM Training:  98%|█████████▊| 623/636 [03:21<00:03,  3.29it/s]
# Latent DiT DDPM Training:  98%|█████████▊| 624/636 [03:21<00:03,  3.45it/s]
# Latent DiT DDPM Training:  98%|█████████▊| 625/636 [03:22<00:04,  2.26it/s]
# Latent DiT DDPM Training:  98%|█████████▊| 626/636 [03:23<00:03,  2.58it/s]
# Latent DiT DDPM Training:  99%|█████████▊| 627/636 [03:23<00:04,  2.12it/s]
# Latent DiT DDPM Training:  99%|█████████▊| 628/636 [03:23<00:03,  2.46it/s]
# Latent DiT DDPM Training:  99%|█████████▉| 629/636 [03:24<00:02,  2.75it/s]
# Latent DiT DDPM Training:  99%|█████████▉| 630/636 [03:24<00:01,  3.01it/s]
# Latent DiT DDPM Training:  99%|█████████▉| 631/636 [03:24<00:01,  3.22it/s]
# Latent DiT DDPM Training:  99%|█████████▉| 632/636 [03:24<00:01,  3.40it/s]
# Latent DiT DDPM Training: 100%|█████████▉| 633/636 [03:25<00:01,  1.95it/s]
# Latent DiT DDPM Training: 100%|█████████▉| 634/636 [03:26<00:00,  2.29it/s]
# Latent DiT DDPM Training: 100%|█████████▉| 635/636 [03:26<00:00,  2.28it/s]
# Diffusion validation: 100%|██████████| 78/78 [00:26<00:00,  4.34it/s]8it/s]Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.7372676..3.2175174].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.85629475..3.4991262].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-3.254082..3.683808].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.93744826..4.142063].
# Diffusion validation: 100%|██████████| 78/78 [00:27<00:00,  2.81it/s]
# Latent DiT DDPM Training: 100%|██████████| 636/636 [03:54<00:00,  2.71it/s]
# Latent DiT DDPM Training:   9%|▉         | 60/636 [00:19<02:30,  3.83it/s]
