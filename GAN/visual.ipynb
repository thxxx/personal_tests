# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
for i in range(25):
    img = Image.open(f"./output/valid_{i}.png")
    
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
import torch

a = torch.randn(2, 4)
print(a.shape)
# Out:
# torch.Size([2, 4])

# %%
a
# Out:
# tensor([[ 1.0810, -0.9731, -0.6328,  0.4139],
#         [ 0.1020, -0.9831,  1.9936,  0.7102]])

# %%
torch.where(a>0.5, 1, 0)
# Out:
# tensor([[1, 0, 0, 0],
#         [0, 0, 1, 1]])
